# %%
df = pd.read_csv("../data/relevant_news.csv")

print(df.shape)
print(df[["title","fmcg_signal_count","deal_signal_count"]].head(20))
# Out:
# (8, 10)
#                                                title  fmcg_signal_count  \
# 0  Atom XVII seeks Rs 75 Cr for consumer startup ...                  0
# 1  Capstone Partners taps Yogesh Punjabi to lead ...                  0
# 2  K Hospitality Corp Unveils Kliff Ventures, an ...                  0
# 3  Sebi proposes easing margin trading funding ru...                  0
# 4  Sebi board to consider reintroducing open-mark...                  0
# 5  Madhu Kela to become investor in Lloyds Engine...                  0
# 6  NSE IPO to create significant value for invest...                  0
# 7  World Bank Raises India's FY27 Growth Forecast...                  0
#
#    deal_signal_count
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# 5                  4
# 6                  0
# 7                  2

# %%
df.head(10).to_string()
# Out:
# '                                 id                                                                                                                                                                   title                                                                                                                                                                                                                                                                                                                                                                                                                                                url                                                                                                                                                                summary                  published       source_feed                       ingested_at\n0  3ef5ea63302d77da9223fef86ef9ea84                                                                            
# ...
